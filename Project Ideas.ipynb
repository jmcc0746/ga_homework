# %%
#IDEAS

#IDEA 1: Poker Player Behavioural Types

#Overview - analyse if you can discern from prior behaviour what the statistically likelihood a player has to be bluffing
#have a good hand, or being unpredictable. This would allow a player to gauge whether it was worth calling, raising
#or folding, given the probability their own hand would give them of winning ie if they have an average hand but
#their opponent could be categorized as someone who plays conservatively and raises or matches, it would
#help the player decide not to challange this opponent. Be able to develop confidence in the prediction in a players style
#over the course of a game, as the data set increases.

#Data - data from global competitions including all the player hands, the probabilities those hands have of winning
#and the risk/reward these players typically play by. Then cross check that against whether the model has any 
#predictive value. Data access will be the hardest part.

#Analysis required - probabilities & confidence intervals.


#IDEA 2: Farming using agriculture futures

#Overview - to understand whether there is any informational value in using the relative price moves in agriultural
#soft commodity futures to understand what crops to plant, taking into account the seasonality of actually growing
#the crop and the time from planting to harvest. In effect do the commodity futures markets provide an intelligent 
#way to signal to determine what crops to plant.

#Data - futures prices can be extracted from the CFTC website or via bloomberg. Online research will be needed to 
#figure out the gestation period of a variety of crops and times of the year they can be feasibily planted.

#Analysis required - correlations.


#IDEA 3: optimal risk reward in randomized trading strategies

#Overview - to back test random risk reward ratios (stop-loss vs take profit) for liquid financial products. E.G. 
#a random signal is constantly repeated to buy or sell a currency with a designated 0.x% stop and a 0.y% take profit
#run multiple scenarios to see over what horizon and with what ratio this is a profit generating strategy.

#Data - intraday prices to be pulled from reuters or bloomberg or various online vendors.

#Analysis required - random buy/sell signals generated by a monte carlo model, as used in option modelling


#IDEA 4: finding a value for utility

#Overview - compile the average cost of a number of daily tasks that we could do ourselves (e.g. dog walking,
#shirt washing) but choose to pay to outsource. Compare this to average incomes of the people that use that
#use these services, potentially even by geography, and see if there are some industries that are valued
#consistently, others that see huge variation, and whether there are factors that determine that.

#Data - individually source prices of various tasks and index them to locations in Sydney, income distribution
#by demographic and location in Sydney

#Analysis required - correlation analyis.


#IDEA 5: what is the optimal FX transaction charge by currency

#Overview - what is the optimal FX charge from mid when you can estimate how soon you will have offseeting flow?
#By currency, create a function that will determine how much you need to charge customers to protect yourself
#from adverse moves in the currency market, when they lock in an agreed rate at the current time. This will give
#give counterparts an idea of what a fair charge is e.g. if audusd on average moves 0.1% in the time in takes
#to get offsetting flow then the flat charge should be 0.1%

#Data - take intraday FX spot moves and volatility from euters, bloomberg, or online websites

#Analysis required - just calculation based.
